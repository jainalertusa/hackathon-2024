# %% [markdown]
# ## Fetch the Data from Relator.com

# %%
from homeharvest import scrape_property
from datetime import datetime

# %%
# Generate filename based on current timestamp
current_timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"HomeHarvest_pending_{current_timestamp}.csv"

#Fetching all pending properties
properties_pending = scrape_property(
  location="Jersey City, NJ",
  listing_type="pending",  # or (for_sale, for_rent, pending)
  past_days=90,  # sold in last 30 days - listed in last 30 days if (for_sale, for_rent)

  # date_from="2023-05-01", # alternative to past_days
  # date_to="2023-05-28",
  # foreclosure=True
  mls_only=True,  # only fetch MLS listings
)
print(f"Number of properties: {len(properties_pending)}")

# Export to csv
properties_pending.to_csv(filename, index=False)
print(properties_pending.head())
# Out:
# Number of properties: 324
#                                         property_url   mls     mls_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  HCNJ  240011603
# 1  https://www.realtor.com/realestateandhomes-det...  HCNJ  240011507
# 2  https://www.realtor.com/realestateandhomes-det...  HCNJ  240011340
# 3  https://www.realtor.com/realestateandhomes-det...  HCNJ  240011847
# 4  https://www.realtor.com/realestateandhomes-det...  HCNJ  240011404
#
#     status                                               text         style  \
# 0  PENDING  Enjoy spectacular NYC views from your living r...  MULTI_FAMILY
# 1  PENDING  Spacious 2 Bedroom/2 Bath home located in the ...        CONDOS
# 2  PENDING  Come see this lovely two-family home located i...  MULTI_FAMILY
# 3  PENDING                                               <NA>     TOWNHOMES
# 4  PENDING  Charming Prewar 1 Bedroom with Separate Dining...        CONDOS
#
#            full_street_line             street     unit         city  ...  \
# 0             126 Ogden Ave      126 Ogden Ave     <NA>  Jersey City  ...
# 1      444 Jersey Ave Apt 8     444 Jersey Ave    Apt 8  Jersey City  ...
# 2         193 Bartholdi Ave  193 Bartholdi Ave     <NA>  Jersey City  ...
# 3                9 Atlas Ct         9 Atlas Ct     <NA>  Jersey City  ...
# 4  145 Harrison Ave Apt 104   145 Harrison Ave  Apt 104  Jersey City  ...
#
#   parking_garage                                     agent  \
# 0              3                          Andrew Sanderson
# 1           <NA>                             RON ZIMMERMAN
# 2              1  Qizhan "Jack" Yao - Buyer Rebate Realtor
# 3              3                              JOHN BATISTA
# 4           <NA>                               mayra solis
#
#                      agent_email  \
# 0              asanderson@kw.com
# 1        ron.zimmerman@gmail.com
# 2       admin@realmartrealty.com
# 3  john@integratedrealestate.org
# 4      thesolisgroupjc@gmail.com
#
#                                         agent_phones  \
# 0  [{'number': '5055731184', 'type': 'Mobile', 'e...
# 1  [{'number': '2017950100', 'type': 'Office', 'e...
# 2  [{'number': '8883626543', 'type': 'Office', 'e...
# 3  [{'number': '2013690099', 'type': 'Office', 'e...
# 4  [{'number': '2013149809', 'type': 'Mobile', 'e...
#
#                                       broker    broker_phone  \
# 0                             Exp Realty Llc  (866) 201-6210
# 1                             Liberty Realty  (201) 222-2900
# 2                       Realmart Realty LLC.  (732) 727-2285
# 3  INTEGRATED REAL ESTATE AND MANAGEMENT LLC            <NA>
# 4                   NEW AND MODERN GROUP LLC  (201) 957-3574
#
#                               broker_website  \
# 0                                       <NA>
# 1              http://www.libertyrealty.com/
# 2                    http://WWW.REALMART.COM
# 3                                       <NA>
# 4  http://HTTPS://WWW.NEWANDMODERNAGENT.COM/
#
#                                       nearby_schools  \
# 0  Jersey City Public School District, M.E.T.S. C...
# 1  Beloved Community Charter School, Jersey City ...
# 2  Jersey City Public School District, Soaraing H...
# 3  Jersey City Public School District, Soaraing H...
# 4                 Jersey City Public School District
#
#                                        primary_photo  \
# 0  http://ap.rdcpix.com/0821eb364f2288c32ab9e2aa4...
# 1  http://ap.rdcpix.com/2aa590941d312db1fcd482912...
# 2  http://ap.rdcpix.com/42749348012a5a47a16038a3b...
# 3  http://ap.rdcpix.com/1bcba2ffb2a6f5e5159cbbade...
# 4  http://ap.rdcpix.com/befbc73a764f04d0d8fcef31c...
#
#                                           alt_photos
# 0  http://ap.rdcpix.com/0821eb364f2288c32ab9e2aa4...
# 1  http://ap.rdcpix.com/2aa590941d312db1fcd482912...
# 2  http://ap.rdcpix.com/42749348012a5a47a16038a3b...
# 3  http://ap.rdcpix.com/1bcba2ffb2a6f5e5159cbbade...
# 4  http://ap.rdcpix.com/befbc73a764f04d0d8fcef31c...
#
# [5 rows x 43 columns]

# %%
# Fetch all rent properties
filename = f"HomeHarvest_for_rent_{current_timestamp}.csv"

properties_for_rent = scrape_property(
  location="Jersey City, NJ",
  listing_type="for_rent",  # or (for_sale, for_rent, pending)
  past_days=90,  # sold in last 30 days - listed in last 30 days if (for_sale, for_rent)

  # date_from="2023-05-01", # alternative to past_days
  # date_to="2023-05-28",
  # foreclosure=True
  mls_only=True,  # only fetch MLS listings
)
print(f"Number of properties: {len(properties_for_rent)}")

# Export to csv
properties_for_rent.to_csv(filename, index=False)
print(properties_for_rent.head())
# Out:
# Number of properties: 1072
#                                         property_url   mls     mls_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  BCNJ   24020090
# 1  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012107
# 2  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012100
# 3  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012098
# 4  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012111
#
#      status                                               text         style  \
# 0  FOR_RENT                                               <NA>  MULTI_FAMILY
# 1  FOR_RENT  Tenant occupied. 24 hours notice is preferred....  MULTI_FAMILY
# 2  FOR_RENT  3 bed 2 bath in MicGnley Square Section! Beaut...  MULTI_FAMILY
# 3  FOR_RENT  Section 8 welcome! Come view this cozy 2 Bedro...  MULTI_FAMILY
# 4  FOR_RENT  Beautiful 1-Bedroom Apartment Available Now! C...     APARTMENT
#
#             full_street_line             street      unit         city  ...  \
# 0          69 Greenville Ave  69 Greenville Ave      <NA>  Jersey City  ...
# 1      16 Bennett St Apt 405      16 Bennett St   Apt 405  Jersey City  ...
# 2    112 Duncan Ave Unit 2RR     112 Duncan Ave  Unit 2RR  Jersey City  ...
# 3  344 Virginia Ave Unit 1RR   344 Virginia Ave  Unit 1RR  Jersey City  ...
# 4      163 Baldwin Ave Apt 5    163 Baldwin Ave     Apt 5  Jersey City  ...
#
#   parking_garage                 agent                          agent_email  \
# 0           <NA>          Bibi Nobrega                                 <NA>
# 1           <NA>        Natalie Costas               nat_costas@outlook.com
# 2           <NA>  Kasey Rosales-garces  kasey.garces@citylivingrealtors.com
# 3           <NA>  Kasey Rosales-garces  kasey.garces@citylivingrealtors.com
# 4           <NA>          Diane Rivera       forsalebydianerivera@gmail.com
#
#                                         agent_phones  \
# 0                                               <NA>
# 1  [{'number': '(201) 433-1111', 'type': 'Office'...
# 2  [{'number': '(201) 559-6868', 'type': 'Office'...
# 3  [{'number': '(201) 559-6868', 'type': 'Office'...
# 4  [{'number': '9086883311', 'type': 'Office', 'e...
#
#                                    broker    broker_phone  \
# 0  CHRISTIE'S INT. REAL ESTATE NNJ Mahwah  (201) 690-1495
# 1                 COMPASS NEW JERSEY, LLC  (201) 627-4947
# 2              CITYLIVING REAL ESTATE LLC  (201) 559-6868
# 3              CITYLIVING REAL ESTATE LLC  (201) 559-6868
# 4       CENTURY 21 Preferred Realty, Inc.  (855) 407-2449
#
#              broker_website  \
# 0    www.christiesrennj.com
# 1  HTTPS://WWW.COMPASS.COM/
# 2                      <NA>
# 3                      <NA>
# 4     https://www.c21p.com/
#
#                                       nearby_schools  \
# 0  Jersey City Public School District, University...
# 1  Jersey City Public School District, Empowermen...
# 2  Jersey City Public School District, Hudson Cou...
# 3  Jersey City Public School District, Empowermen...
# 4  Jersey City Public School District, Hudson Cou...
#
#                                        primary_photo  \
# 0                                               <NA>
# 1  http://ap.rdcpix.com/391f538c00a14372cef655e5f...
# 2  http://ap.rdcpix.com/cf4d14f102968cd3dcc70ff18...
# 3  http://ap.rdcpix.com/b81b91d032ac9871e43eec2c4...
# 4  http://ap.rdcpix.com/3f863a9c90c2152f2daa72eb1...
#
#                                           alt_photos
# 0                                               <NA>
# 1  http://ap.rdcpix.com/391f538c00a14372cef655e5f...
# 2  http://ap.rdcpix.com/cf4d14f102968cd3dcc70ff18...
# 3  http://ap.rdcpix.com/b81b91d032ac9871e43eec2c4...
# 4  http://ap.rdcpix.com/3f863a9c90c2152f2daa72eb1...
#
# [5 rows x 43 columns]

# %%
# Fetch all sold properties
filename = f"HomeHarvest_for_sale_{current_timestamp}.csv"
properties_for_sale = scrape_property(
  location="Jersey City, NJ",
  listing_type="for_sale",  # or (for_sale, for_rent, pending)
  past_days=90,  # sold in last 30 days - listed in last 30 days if (for_sale, for_rent)

  # date_from="2023-05-01", # alternative to past_days
  # date_to="2023-05-28",
  # foreclosure=True
  mls_only=True,  # only fetch MLS listings
)
print(f"Number of properties: {len(properties_for_sale)}")

# Export to csv
properties_for_sale.to_csv(filename, index=False)
print(properties_for_sale.head())
# Out:
# Number of properties: 1091
#                                         property_url   mls     mls_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012066
# 1  https://www.realtor.com/realestateandhomes-det...  BCNJ   24020045
# 2  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012056
# 3  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012053
# 4  https://www.realtor.com/realestateandhomes-det...  HCNJ  240012076
#
#      status                                               text          style  \
# 0  FOR_SALE  Huge, well-maintained two family home on quiet...   MULTI_FAMILY
# 1  FOR_SALE  Welcome to the epitome of sublime urban living...         CONDOS
# 2  FOR_SALE  Presenting 186 Hutton, a Brand-New Luxury Dupl...         CONDOS
# 3  FOR_SALE  Martin Luther King Drive to Virginia Avenue Re...  SINGLE_FAMILY
# 4  FOR_SALE  Welcome to the quintessential epitome of subli...         CONDOS
#
#            full_street_line             street    unit         city  ...  \
# 0             87 Linden Ave      87 Linden Ave    <NA>  Jersey City  ...
# 1  247 Montgomery St Unit B  247 Montgomery St  Unit B  Jersey City  ...
# 2      186 Hutton St Unit B      186 Hutton St  Unit B  Jersey City  ...
# 3           77 Virginia Ave    77 Virginia Ave    <NA>  Jersey City  ...
# 4  247 Montgomery St Unit B  247 Montgomery St  Unit B  Jersey City  ...
#
#   parking_garage           agent             agent_email  \
# 0              3     BELLSTEVENL  sbellrealtor@gmail.com
# 1           <NA>    Lisa Cataldi  lisa.cataldi@gmail.com
# 2              1    Brent Blythe  Brent@newandmodern.com
# 3              1  Tovia Lichtman    tovialicht@gmail.com
# 4           <NA>    Lisa Cataldi  lisa.cataldi@gmail.com
#
#                                         agent_phones  \
# 0  [{'number': '(201) 451-0950', 'type': 'Home', ...
# 1  [{'number': '2012234207', 'type': 'Office', 'e...
# 2  [{'number': '2019573574', 'type': 'Mobile', 'e...
# 3                                               <NA>
# 4  [{'number': '2012234207', 'type': 'Office', 'e...
#
#                                               broker    broker_phone  \
# 0                                       BOYNE REALTY  (201) 451-0950
# 1  Prominent Properties Sotheby's International R...  (201) 223-4207
# 2                           NEW AND MODERN GROUP LLC  (201) 957-3574
# 3             KELLER WILLIAMS MID-TOWN DIRECT REALTY  (973) 762-5400
# 4  Prominent Properties Sotheby's International R...  (201) 223-4207
#
#                               broker_website  \
# 0               http://WWW.BOYNEREALTYJC.COM
# 1       https://www.prominentproperties.com/
# 2  http://HTTPS://WWW.NEWANDMODERNAGENT.COM/
# 3                                       <NA>
# 4       https://www.prominentproperties.com/
#
#                                       nearby_schools  \
# 0  Jersey City Public School District, Jersey Cit...
# 1  Beloved Community Charter School, Jersey City ...
# 2  Jersey City Public School District, Jersey Cit...
# 3  Jersey City Public School District, Dr Lena Ed...
# 4  Beloved Community Charter School, Jersey City ...
#
#                                        primary_photo  \
# 0  http://ap.rdcpix.com/8872c28596a57508b5aaf70a2...
# 1  http://ap.rdcpix.com/a7f6e72273e5849065b70636f...
# 2  http://ap.rdcpix.com/38271ccdedaf718aa1a11dd4f...
# 3  http://ap.rdcpix.com/6d8266e6c2bfcc83a7cd784e2...
# 4  http://ap.rdcpix.com/b057f167812a83f186f19cac4...
#
#                                           alt_photos
# 0  http://ap.rdcpix.com/8872c28596a57508b5aaf70a2...
# 1  http://ap.rdcpix.com/a7f6e72273e5849065b70636f...
# 2  http://ap.rdcpix.com/38271ccdedaf718aa1a11dd4f...
# 3  http://ap.rdcpix.com/6d8266e6c2bfcc83a7cd784e2...
# 4  http://ap.rdcpix.com/b057f167812a83f186f19cac4...
#
# [5 rows x 43 columns]

# %%
# Fetch all sold properties
filename = f"HomeHarvest_sold_{current_timestamp}.csv"
properties_for_sale = scrape_property(
  location="Jersey City, NJ",
  listing_type="sold",  # or (for_sale, for_rent, pending)
  past_days=90,  # sold in last 30 days - listed in last 30 days if (for_sale, for_rent)

  # date_from="2023-05-01", # alternative to past_days
  # date_to="2023-05-28",
  # foreclosure=True
  mls_only=True,  # only fetch MLS listings
)
print(f"Number of properties: {len(properties_for_sale)}")

# Export to csv
properties_sold.to_csv(filename, index=False)
print(properties_sold.head())
